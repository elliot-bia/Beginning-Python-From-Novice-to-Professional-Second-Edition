# %% [markdown]
# dir()

# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
a = 1

# %%
a
# Out:
# 1

# %%
type(a)
# Out:
# int

# %%
3+8
# Out:
# 11

# %%
3 - 5
# Out:
# -2

# %%
5 //  6 #整除
# Out:
# 0

# %%
3%2
# Out:
# 1

# %%
number = 111_222_333

# %%
number
# Out:
# 111222333

# %%
6.4 % 5 #计算时转换成二进制，会有精度损失
# Out:
# 1.4000000000000004

# %% [markdown]
# # 内置类型，内置函数和标准库

# %%
import random
random.randint(4,9)
# Out:
# 6

# %%
import random

ratio = 0.5

num1 = random.randint(3,10) * ratio
print(int(num1))
# Out:
# 3

# %%
import math

round(3.9)
# Out:
# 4

# %%
math.ceil(3.1)
# Out:
# 4

# %%
math.exp(4.9)
# Out:
# 134.28977968493552

# %% [markdown]
# # 字符串 str/string

# %%
"string"
# Out:
# 'string'

# %%
'strint'
# Out:
# 'strint'

# %%
"""w d 
swfw
wef"""
# Out:
# 'w d \nswfw\nwef'

# %%
"isuahfw\
fjehw\
foiwehjf"
# Out:
# 'isuahfwfjehwfoiwehjf'

# %% [markdown]
# # list

# %%
# new
my_list = [3, 4, 5, 6]

# %%
my_list
# Out:
# [3, 4, 5, 6]

# %%
my_list2 = list((3, 4, 5, 6, 7))

# %%
my_list2
# Out:
# [3, 4, 5, 6, 7]

# %%
multi_list = [1, 2, 3, 'Elliot', True, 1.2]

# %%
multi_list
# Out:
# [1, 2, 3, 'Elliot', True, 1.2]

# %%
more_list = [1, 2, 3, [4,4,4,4,4], 5, 6]

# %%
more_list
# Out:
# [1, 2, 3, [4, 4, 4, 4, 4], 5, 6]

# %%
str_list = []

# %%
str_list
# Out:
# []

# %%
str_list.append('a')

# %%
str_list.append(4)

# %%
str_list
# Out:
# ['a', 4]

# %%
str_list = ['c' * 3]

# %%
str_list
# Out:
# ['ccc']

# %%
str_list = [['c'] * 3]

# %%
str_list
# Out:
# [['c', 'c', 'c']]
